# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# !ls
# Out:
# constituents.csv  pulled-data  read_sample.ipynb  sectors_divide.ipynb

# %%
import os
directory = "~/finance/yfinance-pull/"
#
for filename in os.listdir("pulled-data"):
    exec(filename[:-4]+" = pd.read_csv('"+directory+"pulled-data/"+filename+"')")

# %%
Health_Care.head(2)
# Out:
#          Date       ABT  ABBV      ABMD         A      ALXN      ALGN  \
# 0  2010-11-01  0.000000   0.0  0.000000  0.000000  0.000000  0.000000
# 1  2010-11-02  0.005534   0.0  0.025862  0.008921  0.027745  0.012245
#
#         ABC      AMGN      ANTM  ...       COO       TMO       UNH       UHS  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 1 -0.025618 -0.001567  0.018823  ...  0.018358 -0.002133  0.024647  0.006105
#
#         VAR      VRTX       WAT       WST       ZBH  ZTS
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 1 -0.002074 -0.017655  0.007333  0.031503  0.018503  0.0
#
# [2 rows x 62 columns]

# %%
df = Health_Care.copy()
date = df["Date"]
df.drop(["Date"], axis = 1, inplace = True)

for name in df:
    for i in range(0, len(df)):
        df[name].iloc[i] = float(df[name].iloc[i]) + 1

#so that we see how much a stock has changed in %

# %%
df.set_index(pd.to_datetime(date), inplace = True)

# %%
df.cumprod().plot(figsize = (20, 6))
# Out:
# <AxesSubplot:xlabel='Date'>
